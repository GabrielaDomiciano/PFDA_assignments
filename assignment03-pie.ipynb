# %% [markdown]
# Gabriela Domiciano
#
# The note book should have a nice pie chart of peoples email domains in the csv file at the url

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('https://drive.google.com/uc?id=1AWPf-pJodJKeHsARQK_RHiNsE8fjPCVK&export=download')

# %%
df
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %%
df = df.dropna()
display(df)
# Out:
#      Index          User Id First Name Last Name     Sex  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                              Email                  Phone Date of birth  \
# 0              pwarner@example.org           857.139.8239    2014-01-27
# 1    fergusonkatherine@example.net        +1-950-759-8687    1931-07-26
# ...

# %%
email_df = df['Email']
display(email_df)
# Out:
# 0                pwarner@example.org
# 1      fergusonkatherine@example.net
# 2                fhoward@example.org
# 3              zjohnston@example.com
# 4                   elin@example.net
#                    ...
# 995           lyonsdaisy@example.net
# 996          dariusbryan@example.com
# 997           georgechan@example.org
# 998              wanda04@example.net
# 999          deannablack@example.org
# Name: Email, Length: 1000, dtype: object

# %%
email_types = df['Email'].unique()
print(email_types)
# Out:
# ['pwarner@example.org' 'fergusonkatherine@example.net'
#  'fhoward@example.org' 'zjohnston@example.com' 'elin@example.net'
#  'kaitlin13@example.net' 'jeffharvey@example.com' 'alicia33@example.org'
#  'jake50@example.com' 'lanechristina@example.net' 'ncantu@example.com'
#  'kristy41@example.net' 'brandy23@example.com' 'dleon@example.org'
#  'latasha46@example.org' 'stricklandomar@example.org'
#  'twilkinson@example.com' 'dorothymeza@example.com' 'estesana@example.org'
#  'allison66@example.net' 'jordankelley@example.com'
#  'ehatfield@example.com' 'lanedarius@example.com'
#  'samanthasummers@example.org' 'leblancjohnathan@example.org'
#  'jay82@example.net' 'sara05@example.org' 'nelsonlori@example.org'
#  'phillip27@example.net' 'jimsellers@example.com'
#  'jadecollier@example.com' 'george75@example.org'
#  'ramosjonathon@example.org' 'hessrachel@example.com'
#  'fhughes@example.org' 'marilyn91@example.org' 'ebranch@example.net'
# ...

# %%
email_counts = df['Email'].value_counts()
print(email_counts)
# Out:
# Email
# pwarner@example.org           1
# jhancock@example.com          1
# joel78@example.com            1
# koneal@example.net            1
# uharrell@example.org          1
#                              ..
# ohorn@example.com             1
# morganwendy@example.net       1
# cherylmcmillan@example.org    1
# balldrew@example.net          1
# deannablack@example.org       1
# Name: count, Length: 1000, dtype: int64

# %%
email_types = df['Email'].value_counts()
print(email_types)

 = ['Biscoe', 'Dream', 'Torgesen'] 
fig = plt.figure(figsize =(10, 7)) 
plt.pie(data, labels=island) 
plt.title('Number of penguins per Island')
plt.legend(title='Quantity per island', labels=data)

plt.show()
# Out:
# Email
# pwarner@example.org           1
# jhancock@example.com          1
# joel78@example.com            1
# koneal@example.net            1
# uharrell@example.org          1
#                              ..
# ohorn@example.com             1
# morganwendy@example.net       1
# cherylmcmillan@example.org    1
# balldrew@example.net          1
# deannablack@example.org       1
# Name: count, Length: 1000, dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 6
#       4 island = ['Biscoe', 'Dream', 'Torgesen']
#       5 fig = plt.figure(figsize =(10, 7))
# ----> 6 plt.pie(data, labels=island)
#       7 plt.title('Number of penguins per Island')
#       8 plt.legend(title='Quantity per island', labels=data)
#
# NameError: name 'data' is not defined

# %%
email_counts = df['Email'].value_counts()

# Criar o gráfico de pizza
plt.figure(figsize=(8, 8))
plt.pie(email_counts, labels=email_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribuição dos Tipos de E-mails')
plt.axis('equal')  # Garantir que o gráfico fique circular
plt.show()
