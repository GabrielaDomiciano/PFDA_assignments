# %% [markdown]
# ## Assignment 2 weather
# #### Gabriela Domiciano Avellar
#
#
#  - Create a jupyter notebook that has a nice plot of the temperature over time
#
#  ( "dryBulbTemperature_Celsius" ).
#  *****************************

# %% [markdown]
# Soucers:
#
# https://learn.sparkfun.com/tutorials/graph-sensor-data-with-python-and-matplotlib/plot-sensor-data - This tutorial from SparkFun demonstrates how to use Python and Matplotlib to plot sensor data by setting up code, reading data from sensors, and creating visualizations
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.line.html - I used the Pandas documentation to learn about the DataFrame.plot.line method for creating line plots
#
# https://www.geeksforgeeks.org/time-series-plot-or-line-plot-with-pandas/ - I used the GeeksforGeeks site to learn how to create time series plots with Pandas.
#
# https://www.w3schools.com/python/matplotlib_labels.asp - Used o set font properties for titles and labels
#
# https://matplotlib.org/stable/users/explain/quick_start.html -  I used the Matplotlib site to understand the basics of creating plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.dates as mdates

# %%
# Let's take a look at the Dataset.
weather_df = pd.read_csv('weatherreadings1.csv')
display(weather_df)
# Out:
#                                   siteId        reportStartDateTime  \
# 0   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:15:00+00:00
# 1   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:45:00+00:00
# 2   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:00:00+00:00
# 3   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:15:00+00:00
# 4   f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:30:00+00:00
# ..                                   ...                        ...
# 84  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:00:00+00:00
# 85  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:15:00+00:00
# 86  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:30:00+00:00
# 87  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T14:45:00+00:00
# 88  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-03T15:00:00+00:00
#
#             reportEndDateTime  collectionName  isPublic  isLatestVersion  \
# 0   2024-10-02T16:15:00+00:00               1      True             True
# ...

# %%
# Let’s have a closer look at the time and temperature columns:
temperature = weather_df[['reportStartDateTime', 'dryBulbTemperature_Celsius']]
# Show.
print(temperature)
# Out:
#           reportStartDateTime  dryBulbTemperature_Celsius
# 0   2024-10-02T16:15:00+00:00                   15.944444
# 1   2024-10-02T16:45:00+00:00                   15.777778
# 2   2024-10-02T17:00:00+00:00                   15.111111
# 3   2024-10-02T17:15:00+00:00                   14.277778
# 4   2024-10-02T17:30:00+00:00                   13.666667
# ..                        ...                         ...
# 84  2024-10-03T14:00:00+00:00                   14.611111
# 85  2024-10-03T14:15:00+00:00                   14.944444
# 86  2024-10-03T14:30:00+00:00                   14.944444
# 87  2024-10-03T14:45:00+00:00                   14.944444
# 88  2024-10-03T15:00:00+00:00                   14.722222
#
# [89 rows x 2 columns]

# %%
#formatting the data 
datetime = temperature[['reportStartDateTime']]
print(datetime)
# Out:
#           reportStartDateTime
# 0   2024-10-02T16:15:00+00:00
# 1   2024-10-02T16:45:00+00:00
# 2   2024-10-02T17:00:00+00:00
# 3   2024-10-02T17:15:00+00:00
# 4   2024-10-02T17:30:00+00:00
# ..                        ...
# 84  2024-10-03T14:00:00+00:00
# 85  2024-10-03T14:15:00+00:00
# 86  2024-10-03T14:30:00+00:00
# 87  2024-10-03T14:45:00+00:00
# 88  2024-10-03T15:00:00+00:00
#
# [89 rows x 1 columns]

# %%
temperature_celsius = temperature[['dryBulbTemperature_Celsius']]
# Show.
print(temperature_celsius)
# Out:
#     dryBulbTemperature_Celsius
# 0                    15.944444
# 1                    15.777778
# 2                    15.111111
# 3                    14.277778
# 4                    13.666667
# ..                         ...
# 84                   14.611111
# 85                   14.944444
# 86                   14.944444
# 87                   14.944444
# 88                   14.722222
#
# [89 rows x 1 columns]

# %%
#new_names = {'dryBulbTemperature_Celsi':'Temperature_℃'}
#data = weather_df.rename(columns=new_names)

# %%
# Using reportStartDateTime on the x-axis and dryBulbTemperature_Celsius on the y-axis. 
#The plot uses dashed lines (linestyle='dashed') and sets the line width to 2 (linewidth='2').
temperature.plot('reportStartDateTime' , 'dryBulbTemperature_Celsius', linestyle = 'dashed', linewidth = '2')

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

# Title.
plt.title('Temperature Over Time (℃)', fontdict = font1, loc = 'left')

# Axis labels.
plt.xlabel('Report Start Date Time', fontdict = font2, color = 'r')
plt.ylabel('Dry Bulb Temperature (℃)', fontdict = font2, color = 'r')
#rotated the x-axis labels by 45 degrees to make them easier to read.
plt.xticks(rotation=45, ha='right')
plt.subplots_adjust(bottom=0.30)
plt.show()
plt.savefig('/Users/gabrieladomicianoavellar/Desktop/PFDA_assignments/plot/temperature_over_time.png')

# %% [markdown]
# END
# *******
